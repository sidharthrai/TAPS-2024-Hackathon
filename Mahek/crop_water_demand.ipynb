# %%
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
 
#Reading the arable data
arable_data = pd.read_excel("../Data/sensor_data/24 KSU TAPS Arable.xlsx", sheet_name=None, skiprows=2)
Team_2_data = arable_data["Team #2 Data"]
Team_4_data = arable_data["Team #4 Data"]
Team_5_data = arable_data["Team #5 Data"]
Team_13_data = arable_data["Team #13 Data"]
Team_15_data = arable_data["Team #15 Data"]
Team_16_data = arable_data["Team #16 Data"]
Team_18_data = arable_data["Team #18 Data"]
Team_21_data = arable_data["Team #21 Data"]
Team_22_data = arable_data["Team #22 Data"]
Team_26_data = arable_data["Team #26 Data"]
Team_27_data = arable_data["Team #27 Data"]
Team_28_data = arable_data["Team #28 Data"]

# %%
data = [Team_2_data, Team_4_data, Team_5_data, Team_13_data, Team_15_data, Team_16_data, Team_18_data,
       Team_21_data, Team_22_data, Team_26_data, Team_27_data, Team_28_data]

# %%
#Graph for team 2
fig = px.line(data[0], x=data[0]['Timestamp'], 
              y=data[0]["Arable Canopy Evapotranspiration (mm)"]+data[0]["Arable Field Evapotranspiration (mm)"])
fig.update_layout(width=1000, height=500,
                 title={'text': 'Crop Water Demand Over Time for Plot 2', 'x': 0.5},
                 xaxis_title='Time',
                 yaxis_title='Crop Water Demand (mm)')
fig.show()

# %%
#Loop through each DataFrame and add a trace for each
for idx, df in enumerate(data, start=2): 
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        y=df["Arable Canopy Evapotranspiration (mm)"]+df["Arable Field Evapotranspiration (mm)"],
        x=df["Timestamp"],
        name=f'Team_{idx}'
    ))
    # Customize layout
    fig.update_layout(width=1000, height=500,
        title={'text': 'Crop Water Demand Over Time', 'x': 0.5},
        xaxis_title='Time',
        yaxis_title='Crop Water Demand (mm)')

    fig.show()
